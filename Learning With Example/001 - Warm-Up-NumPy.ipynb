# %%
import numpy as np
import math

# %%
x = np.linspace(-math.pi, math.pi, 2000)
x
# Out:
# array([-3.14159265, -3.13844949, -3.13530633, ...,  3.13530633,
#         3.13844949,  3.14159265], shape=(2000,))

# %%
y = np.sin(x)
y
# Out:
# array([-1.22464680e-16, -3.14315906e-03, -6.28628707e-03, ...,
#         6.28628707e-03,  3.14315906e-03,  1.22464680e-16], shape=(2000,))

# %%
# Randomly initialized weights
a = np.random.randn()
b = np.random.randn()
c = np.random.randn()
d = np.random.randn()

a, b, c, d
# Out:
# (-0.17627245226516028,
#  -1.6230622367272731,
#  -0.32318566599718246,
#  0.9442848556380901)

# %%
learning_rate = 1e-6
learning_rate
# Out:
# 1e-06

# %%
# Training Loop
for t in range(3000):
    # Forward Pass: Compute predicted y
    # y = a + b x + c x^2 + d x^3
    y_pred = a + b * x + c * x**2 + d * x**3

    # Compute and print loss
    loss = np.square(y_pred - y).sum()
    if t % 100 == 99:
        print(t, loss)

    # Backpropogate to compute gradients of a, b, c, d with respect to loss
    grad_y_pred = 2.0 * (y_pred - y)
    grad_a = grad_y_pred.sum()
    grad_b = (grad_y_pred * x).sum()
    grad_c = (grad_y_pred * x ** 2).sum()
    grad_d = (grad_y_pred * x ** 3).sum()

    # Update Weights
    a -= learning_rate * grad_a
    b -= learning_rate * grad_b
    c -= learning_rate * grad_c
    d -= learning_rate * grad_d

print(f"Result: y = {a} + {b} x + {c} x^2 + {d} x^3")
# Out:
# 99 4658.441022376015
# 199 3083.784782625782
# 299 2042.4253057352869
# 399 1353.7427189645446
# 499 898.2922022979051
# 599 597.08370379656
# 699 397.8799845660195
# 799 266.13558670627043
# 899 179.0047915215861
# 999 121.3790747530872
# 1099 83.26665666153448
# 1199 58.05957592663034
# 1299 41.387683639872165
# 1399 30.36077000947722
# 1499 23.06736630956934
# 1599 18.24328923862884
# 1699 15.052438693973086
# 1799 12.941831072836163
# 1899 11.545726442081179
# 1999 10.622223008367527
# 2099 10.011323405815926
# 2199 9.607201214254045
# 2299 9.33985878850405
# 2399 9.16299608851191
# 2499 9.045987238658295
# 2599 8.968573821639044
# 2699 8.917354965844474
# 2799 8.883465812005435
# 2899 8.86104197218917
# 2999 8.846203851149443
# Result: y = -0.0006540863934123823 + 0.8515370871670593 x + 0.0001128407869082011 x^2 + -0.09259020007757232 x^3
